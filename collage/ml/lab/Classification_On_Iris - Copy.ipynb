# %% [markdown]
# **Import Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
data = pd.read_csv('Iris.csv')

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.drop(['Id'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.drop(['Id'],axis=1,inplace=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape
# Out:
# (112, 4)

# %%
x_test.shape
# Out:
# (38, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
y_test.shape
# Out:
# (38,)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_new = sc.fit_transform(x_train)
x_test_new = sc.transform(x_test)

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 114           5.8          2.8           5.1          2.4
# 62            6.0          2.2           4.0          1.0
# 33            5.5          4.2           1.4          0.2
# 107           7.3          2.9           6.3          1.8
# 7             5.0          3.4           1.5          0.2
# 100           6.3          3.3           6.0          2.5
# 40            5.0          3.5           1.3          0.3
# 86            6.7          3.1           4.7          1.5
# 76            6.8          2.8           4.8          1.4
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 54            6.5          2.8           4.6          1.5
# 63            6.1          2.9           4.7          1.4
# ...

# %%
from sklearn.svm import SVC
svm_classifier = SVC()
svm_classifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = svm_classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
from sklearn.svm import SVC
svm_classifier2 = SVC(kernel='linear')
svm_classifier2.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_2 = svm_classifier2.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred_2)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
from sklearn.svm import SVC
svm_classifier3 = SVC(kernel='poly')
svm_classifier3.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
y_pred_3 = svm_classifier3.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred_3)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %%
from sklearn.svm import SVC
svm_classifier4 = SVC(kernel='sigmoid')
svm_classifier4.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred_4 = svm_classifier4.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred_4)
cm
# Out:
# array([[ 0,  0, 13],
#        [ 0,  0, 16],
#        [ 0,  0,  9]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion='entropy')
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
y_pred_rfc = rfc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc1 = RandomForestClassifier(n_estimators=10,criterion='entropy')
rfc1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred_rfc1 = rfc1.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc1))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc2 = RandomForestClassifier(n_estimators=20,criterion='entropy')
rfc2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=20)

# %%
y_pred_rfc2 = rfc2.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc2))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc3 = RandomForestClassifier(n_estimators=30,criterion='entropy')
rfc3.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=30)

# %%
y_pred_rfc3 = rfc3.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc3))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc4 = RandomForestClassifier(n_estimators=40,criterion='entropy')
rfc4.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=40)

# %%
y_pred_rfc4 = rfc4.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc4))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc5 = RandomForestClassifier(n_estimators=50,criterion='entropy')
rfc5.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=50)

# %%
y_pred_rfc5 = rfc5.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred_rfc5))
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]
